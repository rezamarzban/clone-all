# %% [markdown]
# <a href="https://colab.research.google.com/github/rezamarzban/clone-all/blob/main/example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !rm -r -f *

# %%
# !git clone https://github.com/rezamarzban/clone-all
# %cd clone-all
# !python github-clone-all.py --clone-user rezamarzban
# Out:
# Cloning into 'clone-all'...
# remote: Enumerating objects: 39, done.
# remote: Counting objects: 100% (39/39), done.
# remote: Compressing objects: 100% (38/38), done.
# remote: Total 39 (delta 14), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (39/39), 17.43 KiB | 8.71 MiB/s, done.
# Resolving deltas: 100% (14/14), done.
# /content/clone-all
# Querying GitHub API...
# > HTTP fetch: https://api.github.com/users/rezamarzban/repos?per_page=100&type=all
#
# Will clone the following repos:
#     * 8086tiny
#     * AI-Hello
#     * AI-TensorFlow.js
#     * AI-TensorFlow.js-draw
#     * ARM926EJ-S
#     * armv5-OpenSSH
#     * armv5-OpenSSL
#     * armv5tej-OpenVPN
#     * Box86Launcher
#     * Browser-localstorage
#     * CamAnalyzerTemplate
#     * Camera-tflite-FTP
#     * Camera2FTP
#     * CLI-Image
#     * clone-all
#     * docker-ssh
#     * DockerRDP-SSH
#     * DockerVNC-SSH
#     * electromagnetic
#     * Hello-Assembely
#     * hiding-cryptominers-linux-rootkit
# ...

# %%
# %cd releases
# Out:
# /content/clone-all/releases

# %%
# !python3 lister.py > list.txt
# !cat list.txt
# Out:
# 8086tiny
# AI-Hello
# AI-TensorFlow.js
# AI-TensorFlow.js-draw
# ARM926EJ-S
# armv5-OpenSSH
# armv5-OpenSSL
# armv5tej-OpenVPN
# Box86Launcher
# Browser-localstorage
# CamAnalyzerTemplate
# Camera-tflite-FTP
# Camera2FTP
# CLI-Image
# clone-all
# docker-ssh
# DockerRDP-SSH
# DockerVNC-SSH
# electromagnetic
# Hello-Assembely
# hiding-cryptominers-linux-rootkit
# kivy-android-hello-world
# LaTeX2sympy
# MiniLux
# MiniLux-32bit
# MiniLux-64bit
# MiniLux-X86
# MiniLux-x86_64
# MIPS
# MNIST-C
# mqtt_camera
# Multi-Camera-Person-Tracking-and-Re-Identification
# nn
# opencv-moments
# PHP-V8
# PHP-V8-TensorFlow
# pico-examples
# pico-tflmicro
# polyfit
# portable-octave
# private-quick-run
# pyPHP-LaTeX
# python-php
# QA
# ripMIME
# S2img
# shell
# single-SSH-login
# Socks5-SSH
# syms
# syms-web
# TensorFlow-Node.js
# TensorFlow.js-vis
# tflite
# TFlite-FTPcamera
# TFliteFTP
# TFLiteObjectDetection
# Tiny-ReID-PyTorch
# ubuntu-xrdp
# v380
# V380-remote
# V380-Web
# V380FTP-Telnet
# xmrig
# ...

# %%
# !python3 downloader.py
# Out:
# ...
# Downloaded 8086tiny from 8086tiny
# ...
# Downloaded neurons-model from AI-Hello
# ...
# Downloaded predict-PIL from AI-Hello
# ...
# Downloaded neurons-model from AI-Hello
# ...
# Downloaded Dynamically-Linked-OpenSSH-binaries.zip from armv5-OpenSSH
# ...
# Downloaded libnss_sss.so.2 from armv5-OpenSSH
# ...
# Downloaded OpenSSH-binaries-beta.zip from armv5-OpenSSH
# ...
# Downloaded shared-libs.zip from armv5-OpenSSH
# ...
# Downloaded openvpn from armv5tej-OpenVPN
# ...
# Downloaded app-debug.apk from Camera2FTP
# ...
# Downloaded hello from Hello-Assembely
# ...
# Downloaded MIPS-aarch64 from MIPS
# ...
# Downloaded MIPS-amd64 from MIPS
# ...
# Downloaded MIPS from MIPS
# ...
# Downloaded test from MNIST-C
# ...
# Downloaded app-debugVer1.0.apk from mqtt_camera
# ...
# Downloaded app-debugVer1.1.apk from mqtt_camera
# ...
# Downloaded app-debugVer1.2.apk from mqtt_camera
# ...
# Downloaded app-debugVer1.3.apk from mqtt_camera
# ...
# Downloaded app-debugVer1.4.apk from mqtt_camera
# ...
# Downloaded app-debugVer2.0.apk from mqtt_camera
# ...
# Downloaded app-debugVer2.1.apk from mqtt_camera
# ...

# %%
# %cd /content
# Out:
# /content

# %%
# !zip -r github_backup.zip .
# Out:
# Streaming output truncated to the last 5000 lines.
#   adding: clone-all/TensorFlow-Node.js/data.js (deflated 66%)
#   adding: clone-all/TensorFlow-Node.js/README.md (deflated 55%)
#   adding: clone-all/TensorFlow-Node.js/.git/ (stored 0%)
#   adding: clone-all/TensorFlow-Node.js/.git/ORIG_HEAD (stored 0%)
#   adding: clone-all/TensorFlow-Node.js/.git/info/ (stored 0%)
#   adding: clone-all/TensorFlow-Node.js/.git/info/exclude (deflated 28%)
#   adding: clone-all/TensorFlow-Node.js/.git/config (deflated 31%)
#   adding: clone-all/TensorFlow-Node.js/.git/FETCH_HEAD (deflated 3%)
#   adding: clone-all/TensorFlow-Node.js/.git/packed-refs (deflated 9%)
#   adding: clone-all/TensorFlow-Node.js/.git/HEAD (stored 0%)
#   adding: clone-all/TensorFlow-Node.js/.git/refs/ (stored 0%)
#   adding: clone-all/TensorFlow-Node.js/.git/refs/remotes/ (stored 0%)
#   adding: clone-all/TensorFlow-Node.js/.git/refs/remotes/origin/ (stored 0%)
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp -f github_backup.zip /content/drive/MyDrive
